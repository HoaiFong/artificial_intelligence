# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.head(30)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 0   1924  Chamonix     Skating   Figure skating  AUT           individual
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 3   1924  Chamonix   Bobsleigh        Bobsleigh  BEL             four-man
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 5   1924  Chamonix    Biathlon         Biathlon  FIN      military patrol
# 6   1924  Chamonix     Skating   Figure skating  FIN                pairs
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 8   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 11  1924  Chamonix     Skating    Speed skating  FIN                5000m
# ...

# %%
#Các năm tổ chức thế vận hội 
data['Year'].unique()
# Out:
# array([1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972,
#        1976, 1980, 1984, 1988, 1992, 1994, 1998, 2002, 2006])

# %%
#Các thành phố tổ chức 
data['City'].unique()
# Out:
# array(['Chamonix', 'St. Moritz', 'Lake Placid', 'Garmisch-Partenkirchen',
#        'Oslo', "Cortina d'Ampezzo", 'Squaw Valley', 'Innsbruck',
#        'Grenoble', 'Sapporo', 'Sarajevo', 'Calgary', 'Albertville',
#        'Lillehammer', 'Nagano', 'Salt Lake City', 'Turin'], dtype=object)

# %%
#Các môn thể thaothao
data['Sport'].unique()
# Out:
# array(['Skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon', 'Skiing',
#        'Curling', 'Luge'], dtype=object)

# %%
#các hình thức thi đấu
data['Discipline'].unique()
# Out:
# array(['Figure skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon',
#        'Speed skating', 'Cross Country S', 'Curling', 'Nordic Combined',
#        'Ski Jumping', 'Skeleton', 'Alpine Skiing', 'Luge',
#        'Short Track S.', 'Freestyle Ski.', 'Snowboard'], dtype=object)

# %%
#Tổng các huy chương được trao từ 1924 đến 2006 
data['Medal'].value_counts()
# Out:
# Gold      774
# Silver    773
# Bronze    764
# Name: Medal, dtype: int64

# %%
#giới tính tham gia 
data['Event gender'].value_counts()
# Out:
# M    1386
# W     802
# X     123
# Name: Event gender, dtype: int64

# %%
data['Event'].unique()
# Out:
# array(['individual', 'pairs', 'four-man', 'ice hockey', 'military patrol',
#        '10000m', '1500m', '5000m', '500m', 'combined (4 events)', '18km',
#        'curling', '50km', 'K90 individual (70m)', 'five-man', 'two-man',
#        '4x10km relay', 'alpine combined', 'downhill', 'slalom',
#        'giant slalom', '10km', '30km mass start', '3x5km relay', '15km',
#        '1000m', '20km', '3000m', 'doubles', 'singles', '5km',
#        'K120 individual (90m)', '4x7.5km relay', '4x5km relay',
#        'ice dancing', 'super-G', 'Team', 'K120 team (90m)', '3000m relay',
#        '5000m relay', '3x7.5km relay', '7.5km', '15km mass start', '30km',
#        'Combined 5km + 10km pursuit', 'moguls', '10km pursuit',
#        'Combined 10km + 15km pursuit', 'aerials', 'giant-slalom',
#        'Half-pipe', 'sprint', '5km pursuit', '12.5km pursuit',
#        'Giant parallel slalom', 'Sprint 1.5km', 'sprint 1.5km',
#        'Alpine combined', 'Individual', 'Individual sprint',
# ...

# %%
#Lọc số huy chương vàng 
data[data['Medal']=='Gold']
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 7     1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9     1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...    ...       ...         ...             ...  ...              ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# 2302  2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# 2305  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 1               W  Gold
# 2               X  Gold
# 4               M  Gold
# ...

# %%
#Lọc số huy chương bạcbạc 
data[data['Medal']=='Silver']
# Out:
#       Year      City     Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix   Skating  Figure skating  AUT       individual
# 5     1924  Chamonix  Biathlon        Biathlon  FIN  military patrol
# 6     1924  Chamonix   Skating  Figure skating  FIN            pairs
# 8     1924  Chamonix   Skating   Speed skating  FIN           10000m
# 11    1924  Chamonix   Skating   Speed skating  FIN            5000m
# ...    ...       ...       ...             ...  ...              ...
# 2296  2006     Turin   Skating   Speed skating  USA            1000m
# 2298  2006     Turin   Skating   Speed skating  USA            1500m
# 2306  2006     Turin    Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin    Skiing       Snowboard  USA        Half-pipe
# 2310  2006     Turin    Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 5               M  Silver
# 6               X  Silver
# 8               M  Silver
# ...

# %%
#Lọc số huy chương đồng
data[data['Medal']=='Bronze']
# Out:
#       Year      City      Sport       Discipline  NOC                  Event  \
# 3     1924  Chamonix  Bobsleigh        Bobsleigh  BEL               four-man
# 12    1924  Chamonix    Skating    Speed skating  FIN                   500m
# 13    1924  Chamonix    Skating    Speed skating  FIN    combined (4 events)
# 15    1924  Chamonix     Skiing  Cross Country S  FIN                   18km
# 16    1924  Chamonix   Biathlon         Biathlon  FRA        military patrol
# ...    ...       ...        ...              ...  ...                    ...
# 2291  2006     Turin    Skating   Short Track S.  USA                  1000m
# 2292  2006     Turin    Skating   Short Track S.  USA            5000m relay
# 2297  2006     Turin    Skating    Speed skating  USA                  1500m
# 2303  2006     Turin     Skiing   Freestyle Ski.  USA                 moguls
# 2304  2006     Turin     Skiing        Snowboard  USA  Giant parallel slalom
#
#      Event gender   Medal
# ...

# %%
#Các huy chương đã được trao 
data['Year'].value_counts()
# Out:
# 2006    252
# 2002    234
# 1998    205
# 1994    183
# 1992    171
# 1988    138
# 1984    117
# 1980    115
# 1976    111
# 1968    106
# 1972    105
# 1964    103
# 1960     81
# 1956     72
# 1948     68
# 1952     67
# 1936     51
# 1924     49
# 1932     42
# 1928     41
# Name: Year, dtype: int64

# %%
#Tổng số huy chương của các nước tham gia 
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
#Lọc về các huy chương của nước Đức 
F = data.set_index(data['NOC'])
F.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
#Số huy chương của HungHungary qua các mùa thế vận hội 
H = data.set_index(data['NOC'])
H.loc['HUN']
# Out:
#      Year                    City    Sport      Discipline  NOC        Event  \
# NOC
# HUN  1932             Lake Placid  Skating  Figure skating  HUN        pairs
# HUN  1936  Garmisch-Partenkirchen  Skating  Figure skating  HUN        pairs
# HUN  1948              St. Moritz  Skating  Figure skating  HUN        pairs
# HUN  1952                    Oslo  Skating  Figure skating  HUN        pairs
# HUN  1956       Cortina d'Ampezzo  Skating  Figure skating  HUN        pairs
# HUN  1980             Lake Placid  Skating  Figure skating  HUN  ice dancing
#
#     Event gender   Medal
# NOC
# HUN            X  Bronze
# HUN            X  Bronze
# HUN            X  Silver
# HUN            X  Bronze
# HUN            X  Bronze
# HUN            X  Silver
